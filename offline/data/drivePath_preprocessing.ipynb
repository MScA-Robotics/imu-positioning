# %%
import pickle
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/tammy/Tammy/UChiago/Capstone/Capstone_Implementation/Scraping'

# %% [markdown]
# ### 1.Import data: Go straight

# %%
straight_p1 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_data.pkl')
straight_p2 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_data3.pkl')
straight_p3 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_data4.pkl')
straight_p4 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_data5.pkl')
straight_p1 = pd.DataFrame(straight_p1)
straight_p2 = pd.DataFrame(straight_p2)
straight_p3 = pd.DataFrame(straight_p3)
straight_p4 = pd.DataFrame(straight_p4)

# %%
cols =['time', 'accel_x', 'accel_y', 'accel_z','mag_x', 'mag_y','mag_z','gyro_x', 'gyro_y','gyro_z','euler_x', 'euler_y',  'euler_z', 'right_enc', 'left_enc']

# %%
straight_p1= straight_p1[cols]
straight_p2= straight_p2[cols]
straight_p3= straight_p3[cols]
straight_p4= straight_p4[cols]

# %%
# Direction_Path
straight_p1['path'] = 'S_123_P1'
straight_p2['path'] = 'S_123_P2'
straight_p3['path'] = 'S_123_P3'
straight_p4['path'] = 'S_123_P4'

# %%
# Distance measurement
straight_p1['distance'] = 123.0
straight_p2['distance'] = 123.9
straight_p3['distance'] = 122.5
straight_p4['distance'] = 122.5

# %%
straight_p2
# Out:
#                         time  accel_x  accel_y  accel_z    mag_x     mag_y  \
# 0 2020-02-15 17:40:50.236618     0.09    10.71    -0.71  -5.7500  -65.6875
# 1 2020-02-15 17:40:51.921297    -0.54    10.31    -0.65 -25.7500 -102.5000
# 2 2020-02-15 17:40:53.605065    -0.89    10.08    -2.28 -56.6875 -138.6875
# 3 2020-02-15 17:40:55.288857    -0.15     9.67    -2.93 -52.5625 -107.6875
# 4 2020-02-15 17:40:56.967613    -0.60     9.54    -3.51 -34.3750  -85.7500
#
#      mag_z   gyro_x  gyro_y  gyro_z   euler_x  euler_y  euler_z  right_enc  \
# 0 -24.0625  22.1875  4.7500  3.3750  102.1250  -5.3750  90.5000        431
# 1 -13.3750  36.6250 -0.4375  3.8125  102.0625  -5.6875  90.1250        862
# 2  -0.5625   4.2500  1.3125 -1.1875  101.6250  -5.2500  90.2500       1293
# 3  31.3750  -4.8125  6.5625 -1.5625  102.3125  -5.2500  90.0625       1724
# 4  66.0000  -0.5000 -2.3750  1.2500  103.7500  -5.3750  90.1250       2155
#
#    left_enc      path  distance
# ...

# %% [markdown]
# ### 2.Import data: 25 with 10 degree right turn x 5

# %%
curve_p1 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_2_data_1.pkl')
curve_p2 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_2_data_3.pkl')
curve_p3 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_2_data_4.pkl')
curve_p4 = pd.read_pickle('/Users/tammy/Tammy/UChiago/Robotics_Club/Data/test_drive_data/test_drive_2_data_5.pkl')
curve_p1 = pd.DataFrame(curve_p1)
curve_p2 = pd.DataFrame(curve_p2)
curve_p3 = pd.DataFrame(curve_p3)
curve_p4 = pd.DataFrame(curve_p4)

# %%
curve_p1
# Out:
#    accel_x  gyro_z  accel_y  accel_z     mag_x  gyro_x  right_enc    mag_z  \
# 0    -0.70  0.4375    10.12     0.34   -4.0000  1.2500        411 -15.6875
# 1    -1.53 -4.5000     9.44     0.57  -31.2500 -0.3125        823 -15.3750
# 2    -1.41 -0.3750     9.78    -0.05  -79.7500  1.0000       1235  -0.6875
# 3    -1.51  0.3125     9.80    -0.64 -100.0625  2.3750       1647  32.0000
# 4    -1.10 -0.4375     9.64    -0.47  -90.2500  0.0625       2059  58.5625
#
#     gyro_y   euler_x     mag_y  left_enc  euler_y  euler_z  \
# 0 -12.9375  102.5625  -59.0000       445  -4.9375  90.2500
# 1 -13.5000  111.8750  -96.3750       890  -5.1250  89.1875
# 2 -12.6250  120.3750 -116.0625      1335  -4.6875  88.3750
# 3 -20.1250  128.7500  -99.0625      1780  -4.6875  87.6875
# 4 -11.5625  137.0625  -75.0625      2226  -4.1875  87.5000
#
#                         time
# 0 2020-02-15 17:48:57.828139
# 1 2020-02-15 17:48:59.575993
# 2 2020-02-15 17:49:01.323542
# 3 2020-02-15 17:49:03.074368
# ...

# %%
curve_p1= curve_p1[cols]
curve_p2= curve_p2[cols]
curve_p3= curve_p3[cols]
curve_p4= curve_p4[cols]

# %%
# Direction_Path
curve_p1['path'] = 'C_123_P1'
curve_p2['path'] = 'C_123_P2'
curve_p3['path'] = 'C_123_P3'
curve_p4['path'] = 'C_123_P4'
# Out:
# /Users/tammy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Distance measurement
curve_p1['distance'] = 123.2
curve_p2['distance'] = 123.5
curve_p3['distance'] = 123.9
curve_p4['distance'] = 123.5
# Out:
# /Users/tammy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
curve_p1
# Out:
#                         time  accel_x  accel_y  accel_z     mag_x     mag_y  \
# 0 2020-02-15 17:48:57.828139    -0.70    10.12     0.34   -4.0000  -59.0000
# 1 2020-02-15 17:48:59.575993    -1.53     9.44     0.57  -31.2500  -96.3750
# 2 2020-02-15 17:49:01.323542    -1.41     9.78    -0.05  -79.7500 -116.0625
# 3 2020-02-15 17:49:03.074368    -1.51     9.80    -0.64 -100.0625  -99.0625
# 4 2020-02-15 17:49:04.823097    -1.10     9.64    -0.47  -90.2500  -75.0625
#
#      mag_z  gyro_x   gyro_y  gyro_z   euler_x  euler_y  euler_z  right_enc  \
# 0 -15.6875  1.2500 -12.9375  0.4375  102.5625  -4.9375  90.2500        411
# 1 -15.3750 -0.3125 -13.5000 -4.5000  111.8750  -5.1250  89.1875        823
# 2  -0.6875  1.0000 -12.6250 -0.3750  120.3750  -4.6875  88.3750       1235
